# %% [markdown]
# ## Making MDPs in Python
#
# For the simple environments, we can just hardcode the MDPs into a dictionary by exhaustively encoding the whole state space and the transition function. We will also go through a more complicated example where the state space is too large to be manually coded and we need to implement the transition function based on some state parameters.
#
# You can start this assignment during/after reading Grokking Ch-2.
#
# NOTE: all page numbers referred to in this ipynb notebook refer to Grokking textbook

# %% [markdown]
# ## Environment 0 - Bandit Walk
#
# Let us consider the BW environment on Page 39.
#
# State Space has 3 elements, states 0, 1 and 2.
# States 0 and 2 are terminal states and state 1 is the starting state.
#
# Action space has 2 elements, left and right.
#
# The environment is deterministic - transition probability of any action is 1.
#
# Only 1 (State, Action, State') tuple has positive reward, (1, Right, 2) gives the agent +1 reward.

# %% [markdown]
# We'll model this MDP as a dictionary. This code is an example for the upcoming exercises.

# %%
bw_mdp = {

    0 : {
        "Right" : [(1, 0, 0, True)],
        "Left" : [(1, 0, 0, True)]
    },

    1 : {
        "Right" : [(1, 2, 1, True)],
        "Left" : [(1, 0, 0, True)]
    },

    2 : {
        "Right" : [(1, 2, 0, True)],
        "Left" : [(1, 2, 0, True)]
    }
    
}

# %% [markdown]
# Here we a dictionary bw_mdp which to get the transitions possible we can do bw_mdp\[current state\]\[action to take\]. this will return a list of the possibilities.
#
# The format of each element within the list is
# (probability of that transition , next state , reward , 'is the next state a terminal state?')
#
# Obviously make sure that the sum of probability of all possible transitions is 1

# %% [markdown]
# Note that by convention, all actions from terminal states still lead to the same state with reward 0.

# %% [markdown]
# ## Environment 1 - Slippery Walk
#
# Here, states 0 and 6 are terminal states and state 3 is the starting state.
#
# Action space has again 2 elements, left and right.
#
# The environment is now stochastic, transition probability of any action is as follows -
# If agent chooses `Right` at a non-terminal state,
# - $50\%$ times it will go to `Right` state
# - $33\frac{1}{3} \%$ times it will stay in same state
# - $16\frac{2}{3}\%$ times it will go to `Left`state
#
# And similiarly vice versa for Left(just replace left with right and right with left in previous list)
#
# This time, 2 different (State, Action, State') tuples have positive rewards, you need to find them.

# %% [markdown]
# We'll again model this MDP as a dictionary. Part of the code is written for you.

# %%
swf_mdp = {

    0 : {
        "Right" : [(1, 0, 0, True)],
        "Left" : [(1, 0, 0, True)],
    },

    1 : {
        "Right" : [
            (1/2, 2, 0, False),
            (1/3, 1, 0, False),
            (1/6, 0, 0, True),
        ],
        "Left" : [
            (1/2, 0, 0, True),
            (1/3, 1, 0, False),
            (1/6, 2, 0, False),
        ]
    }, 
    2 : {
        "Right" : [
            (1/2, 3, 0, False),
            (1/3, 2, 0, False),
            (1/6, 1, 0, False),
        ],
        "Left" : [
            (1/2, 1, 0, False),
            (1/3, 2, 0, False),
            (1/6, 3, 0, False),
        ]
    }, 
    3 : {
        "Right" : [
            (1/2, 4, 0, False),
            (1/3, 3, 0, False),
            (1/6, 2, 0, False),
        ],
        "Left" : [
            (1/2, 2, 0, False),
            (1/3, 3, 0, False),
            (1/6, 4, 0, False),
        ]
    }, 
    4 : {
        "Right" : [
            (1/2, 5, 0, False),
            (1/3, 4, 0, False),
            (1/6, 3, 0, False),
        ],
        "Left" : [
            (1/2, 3, 0, False),
            (1/3, 4, 0, False),
            (1/6, 5, 0, False),
        ]
    }, 
    5 :{
        "Right" : [
            (1/2, 6, 1, True),
            (1/3, 5, 0, False),
            (1/6, 4, 0, False),
        ],
        "Left" : [
            (1/2, 4, 0, False),
            (1/3, 5, 0, False),
            (1/6, 6, 1, True),
        ]
    }, 
    6 :{
        "Right" : [(1, 6, 0, True)],
        "Left" : [(1, 6, 0, True)],
    },
    
}

# %% [markdown]
# ## Environment 2 - Frozen Lake Environment
#
# This environment is described on Page 46.
#
# The FL environment has a large state space, so it's better to generate most of the MDP via Python instead of typing stuff manually.
#
# Note that all 5 states - 5, 7, 11, 12, 15 are terminal states, so keep that in mind while constructing the MDP.
#
# There are 4 actions now - Up, Down, Left, Right.
#
# The environment is stochastic, and states at the border of lake will require separate treatment.

# %% [markdown]
# Yet again we will model this MDP as a (large) dictionary.

# %%
fl_mdp = {
    # to be added
}

# %%
terminals=[5,7,11,12,15]
dirs={"Up":-4,"Down":4,"Left":-1,"Right":1}
for state in range(0, 16):

    # add transitions to other states
    transitions = {}

    for action in ["Up", "Down", "Right", "Left"]:
        
        transitions[action]=[]
        if state in terminals:
            k=(state==15)
            transitions[action]=[(1.0,state,int(k),True)]
            continue
        if action=="Up" or action=="Down":
            rtuple=[1/3]
            ltuple=[1/3]
            atuple=[1/3]
            tuples=[rtuple,ltuple,atuple]
            if ((state+1)%4)==0:
                rtuple.append(state)
            else:
                rtuple.append(state+1)
            if ((state-1)%4)==3:
                ltuple.append(state)
            else:
                ltuple.append(state-1) 
            if ((state+dirs[action])<0) or ((state+dirs[action])>15):
                atuple.append(state)
            else:
                atuple.append(state+dirs[action])
            for tup in tuples:
                if tup[1]==15:
                    tup.append(1)
                else:
                    tup.append(0)
                if tup[1] in terminals:
                    tup.append(True)
                else:
                    tup.append(False)
                newtup=tuple(tup)
                transitions[action].append(newtup)
        else:
            utuple=[1/3]
            dtuple=[1/3]
            atuple=[1/3]
            tuples=[utuple,dtuple,atuple]
            if (state-4)<0:
                utuple.append(state)
            else:
                utuple.append(state-4)
            if (state+4)>15:
                dtuple.append(state)
            else:
                dtuple.append(state+4) 
            if ((state+dirs[action])%4)==3 or ((state+dirs[action])%4)==0:
                atuple.append(state)
            else:
                atuple.append(state+dirs[action])
            for tup in tuples:
                if tup[1]==15:
                    tup.append(1)
                else:
                    tup.append(0)
                if tup[1] in terminals:
                    tup.append(True)
                else:
                    tup.append(False)
                newtup=tuple(tup)
                transitions[action].append(newtup)

        continue

    fl_mdp[state] = transitions
print(fl_mdp)
# Out:
 0, False), (0.3333333333333333, 4, 0, False)], 'Down': [(0.3333333333333333, 9, 0, False), (0.3333333333333333, 8, 0, False), (0.3333333333333333, 12, 0, True)], 'Right': [(0.3333333333333333, 4, 0, False), (0.3333333333333333, 12, 0, True), (0.3333333333333333, 9, 0, False)], 'Left': [(0.3333333333333333, 4, 0, False), (0.3333333333333333, 12, 0, True), (0.3333333333333333, 8, 0, False)]}, 9: {'Up': [(0.3333333333333333, 10, 0, False), (0.3333333333333333, 8, 0, False), (0.3333333333333333, 5, 0, True)], 'Down': [(0.3333333333333333, 10, 0, False), (0.3333333333333333, 8, 0, False), (0.3333333333333333, 13, 0, False)], 'Right': [(0.3333333333333333, 5, 0, True), (0.3333333333333333, 13, 0, False), (0.3333333333333333, 10, 0, False)], 'Left': [(0.3333333333333333, 5, 0, True), (0.3333333333333333, 13, 0, False), (0.3333333333333333, 9, 0, False)]}, 10: {'Up': [(0.3333333333333333, 11, 0, True), (0.33333 ...

# %% [markdown]
# You might need to do some stuff manually, but make sure to automate most of it.

# %% [markdown]
# You can check your implementation of the FL environment by comparing it with the one in OpenAI Gym.
# OpenAI Gym basically contains implmentations of common RL MDPs so that we can directly train our agents on test environments.

# %%
import gym
P = gym.make('FrozenLake-v1').env.P
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %% [markdown]
# Since the imported MDP is also just a dictionary, we can just print it.

# %%
# using the pretty print module

import pprint
pprint.pprint(P)
# Out:
# {0: {0: [(0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 4, 0.0, False)],
#      1: [(0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 4, 0.0, False),
#          (0.3333333333333333, 1, 0.0, False)],
#      2: [(0.3333333333333333, 4, 0.0, False),
#          (0.3333333333333333, 1, 0.0, False),
#          (0.3333333333333333, 0, 0.0, False)],
#      3: [(0.3333333333333333, 1, 0.0, False),
#          (0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 0, 0.0, False)]},
#  1: {0: [(0.3333333333333333, 1, 0.0, False),
#          (0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True)],
#      1: [(0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 2, 0.0, False)],
#      2: [(0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 1, 0.0, False)],
#      3: [(0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 1, 0.0, False),
#          (0.3333333333333333, 0, 0.0, False)]},
#  2: {0: [(0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 1, 0.0, False),
#          (0.3333333333333333, 6, 0.0, False)],
#      1: [(0.3333333333333333, 1, 0.0, False),
#          (0.3333333333333333, 6, 0.0, False),
#          (0.3333333333333333, 3, 0.0, False)],
#      2: [(0.3333333333333333, 6, 0.0, False),
#          (0.3333333333333333, 3, 0.0, False),
#          (0.3333333333333333, 2, 0.0, False)],
#      3: [(0.3333333333333333, 3, 0.0, False),
#          (0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 1, 0.0, False)]},
#  3: {0: [(0.3333333333333333, 3, 0.0, False),
#          (0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 7, 0.0, True)],
#      1: [(0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 7, 0.0, True),
#          (0.3333333333333333, 3, 0.0, False)],
#      2: [(0.3333333333333333, 7, 0.0, True),
#          (0.3333333333333333, 3, 0.0, False),
#          (0.3333333333333333, 3, 0.0, False)],
#      3: [(0.3333333333333333, 3, 0.0, False),
#          (0.3333333333333333, 3, 0.0, False),
#          (0.3333333333333333, 2, 0.0, False)]},
#  4: {0: [(0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 4, 0.0, False),
#          (0.3333333333333333, 8, 0.0, False)],
#      1: [(0.3333333333333333, 4, 0.0, False),
#          (0.3333333333333333, 8, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True)],
#      2: [(0.3333333333333333, 8, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 0, 0.0, False)],
#      3: [(0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 4, 0.0, False)]},
#  5: {0: [(1.0, 5, 0, True)],
#      1: [(1.0, 5, 0, True)],
#      2: [(1.0, 5, 0, True)],
#      3: [(1.0, 5, 0, True)]},
#  6: {0: [(0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 10, 0.0, False)],
#      1: [(0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 10, 0.0, False),
#          (0.3333333333333333, 7, 0.0, True)],
#      2: [(0.3333333333333333, 10, 0.0, False),
#          (0.3333333333333333, 7, 0.0, True),
#          (0.3333333333333333, 2, 0.0, False)],
#      3: [(0.3333333333333333, 7, 0.0, True),
#          (0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True)]},
#  7: {0: [(1.0, 7, 0, True)],
#      1: [(1.0, 7, 0, True)],
#      2: [(1.0, 7, 0, True)],
#      3: [(1.0, 7, 0, True)]},
#  8: {0: [(0.3333333333333333, 4, 0.0, False),
#          (0.3333333333333333, 8, 0.0, False),
#          (0.3333333333333333, 12, 0.0, True)],
#      1: [(0.3333333333333333, 8, 0.0, False),
#          (0.3333333333333333, 12, 0.0, True),
#          (0.3333333333333333, 9, 0.0, False)],
#      2: [(0.3333333333333333, 12, 0.0, True),
#          (0.3333333333333333, 9, 0.0, False),
#          (0.3333333333333333, 4, 0.0, False)],
#      3: [(0.3333333333333333, 9, 0.0, False),
#          (0.3333333333333333, 4, 0.0, False),
#          (0.3333333333333333, 8, 0.0, False)]},
#  9: {0: [(0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 8, 0.0, False),
#          (0.3333333333333333, 13, 0.0, False)],
#      1: [(0.3333333333333333, 8, 0.0, False),
#          (0.3333333333333333, 13, 0.0, False),
#          (0.3333333333333333, 10, 0.0, False)],
#      2: [(0.3333333333333333, 13, 0.0, False),
#          (0.3333333333333333, 10, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True)],
#      3: [(0.3333333333333333, 10, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 8, 0.0, False)]},
#  10: {0: [(0.3333333333333333, 6, 0.0, False),
#           (0.3333333333333333, 9, 0.0, False),
#           (0.3333333333333333, 14, 0.0, False)],
#       1: [(0.3333333333333333, 9, 0.0, False),
#           (0.3333333333333333, 14, 0.0, False),
#           (0.3333333333333333, 11, 0.0, True)],
#       2: [(0.3333333333333333, 14, 0.0, False),
#           (0.3333333333333333, 11, 0.0, True),
#           (0.3333333333333333, 6, 0.0, False)],
#       3: [(0.3333333333333333, 11, 0.0, True),
#           (0.3333333333333333, 6, 0.0, False),
#           (0.3333333333333333, 9, 0.0, False)]},
#  11: {0: [(1.0, 11, 0, True)],
#       1: [(1.0, 11, 0, True)],
#       2: [(1.0, 11, 0, True)],
#       3: [(1.0, 11, 0, True)]},
#  12: {0: [(1.0, 12, 0, True)],
#       1: [(1.0, 12, 0, True)],
#       2: [(1.0, 12, 0, True)],
#       3: [(1.0, 12, 0, True)]},
#  13: {0: [(0.3333333333333333, 9, 0.0, False),
#           (0.3333333333333333, 12, 0.0, True),
#           (0.3333333333333333, 13, 0.0, False)],
#       1: [(0.3333333333333333, 12, 0.0, True),
#           (0.3333333333333333, 13, 0.0, False),
#           (0.3333333333333333, 14, 0.0, False)],
#       2: [(0.3333333333333333, 13, 0.0, False),
#           (0.3333333333333333, 14, 0.0, False),
#           (0.3333333333333333, 9, 0.0, False)],
#       3: [(0.3333333333333333, 14, 0.0, False),
#           (0.3333333333333333, 9, 0.0, False),
#           (0.3333333333333333, 12, 0.0, True)]},
#  14: {0: [(0.3333333333333333, 10, 0.0, False),
#           (0.3333333333333333, 13, 0.0, False),
#           (0.3333333333333333, 14, 0.0, False)],
#       1: [(0.3333333333333333, 13, 0.0, False),
#           (0.3333333333333333, 14, 0.0, False),
#           (0.3333333333333333, 15, 1.0, True)],
#       2: [(0.3333333333333333, 14, 0.0, False),
#           (0.3333333333333333, 15, 1.0, True),
#           (0.3333333333333333, 10, 0.0, False)],
#       3: [(0.3333333333333333, 15, 1.0, True),
#           (0.3333333333333333, 10, 0.0, False),
#           (0.3333333333333333, 13, 0.0, False)]},
#  15: {0: [(1.0, 15, 0, True)],
#       1: [(1.0, 15, 0, True)],
#       2: [(1.0, 15, 0, True)],
#       3: [(1.0, 15, 0, True)]}}

# %% [markdown]
# ## Environment 3 - Key Door Game

# %% [markdown]
# Now we will implement a slightly different version of frozen lake without the stochasticity but with the added constraint of a key.
#
# So now we have a 4x4 grid in which some cells are holes(and so terminal) and we have a goal state(keep it as 15) but this time someone locked the goal state with a door :(. Without the key we CANNOT ENTER the goal state.
#
# Luckily for us, that guy was very clumsy and dropped the key in tile 3!. So now make a MDP to represent the process of us escaping this grid world.
#
# Remember that the state in a MDP isnt just the position/location we are in. it should represent our whole game situation. (For example I can either be at tile 14 with the key or at tile 14 without key and these two situations are different and therfore must be represented as **different** states!)

# %% [markdown]
# To summarise
# - state state is 0
# - door/goal state is 15
# - holes at 5, 7, 11, 12
# - key at 3
# - The key is picked up automatically upon entering tile 3
# - can only enter tile 15 when key is obtained(otherwise its like a wall)
# - holes & goal are terminal
# - reward of 1 when reaching tile 15 wiht the key
# - Attempting to enter tile 15 when we DONT have the key should be treated like hitting a wall and bouncing back to the original state where we took that action

# %%
# You can implements any helper function or other variables to help you implement it

holes=[5,7,11,12]
key_tile=3
goal=15
LEFT  = 0
DOWN  = 1
RIGHT = 2
UP    = 3

#actions are LEFT,UP,DOWN, RIGHT and state is a tuple (location,has_key)
def kdg_gen(
    holes,
    goal,
    key_tile,
    grid_size=4
):

    n_positions = grid_size * grid_size
    n_actions = 4

    def to_state_id(pos, has_key):
        return pos * 2 + has_key

    def from_state_id(s):
        return s // 2, s % 2


    def move(pos, action):
        r, c = divmod(pos, grid_size)

        if action == LEFT:
            c -= 1
        elif action == DOWN:
            r += 1
        elif action == RIGHT:
            c += 1
        elif action == UP:
            r -= 1

        if r < 0 or r >= grid_size or c < 0 or c >= grid_size:
            return pos

        return r * grid_size + c

    P = {s: {a: [] for a in range(n_actions)}
         for s in range(n_positions * 2)}

    for pos in range(n_positions):
        for has_key in (0, 1):
            s = to_state_id(pos, has_key)

            if pos in holes or pos == goal:
                for a in range(n_actions):
                    P[s][a] = [(1.0, s, 0.0, True)]
                continue

            for a in range(n_actions):
                next_pos = move(pos, a)

                if next_pos == goal and not has_key:
                    next_pos = pos

                next_has_key = has_key or (next_pos == key_tile)

                reward = 0.0
                done = False

                if next_pos in holes:
                    done = True

                if next_pos == goal and next_has_key:
                    reward = 1.0
                    done = True

                ns = to_state_id(next_pos, next_has_key)

                P[s][a] = [(1.0, ns, reward, done)]

    return P
    

gw_map = kdg_gen(holes,goal,key_tile)
print(gw_map)
# Out:
# {0: {0: [(1.0, 0, 0.0, False)], 1: [(1.0, 8, 0.0, False)], 2: [(1.0, 2, 0.0, False)], 3: [(1.0, 0, 0.0, False)]}, 1: {0: [(1.0, 1, 0.0, False)], 1: [(1.0, 9, 0.0, False)], 2: [(1.0, 3, 0.0, False)], 3: [(1.0, 1, 0.0, False)]}, 2: {0: [(1.0, 0, 0.0, False)], 1: [(1.0, 10, 0.0, True)], 2: [(1.0, 4, 0.0, False)], 3: [(1.0, 2, 0.0, False)]}, 3: {0: [(1.0, 1, 0.0, False)], 1: [(1.0, 11, 0.0, True)
0.0, False)], 2: [(1.0, 23, 0.0, True)], 3: [(1.0, 13, 0.0, False)]}, 22: {0: [(1.0, 22, 0.0, True)], 1: [(1.0, 22, 0.0, True)], 2: [(1.0, 22, 0.0, True)], 3: [(1.0, 22, 0.0, True)]}, 23: {0: [(1.0, 23, 0.0, True)], 1: [(1.0, 23, 0.0, True)], 2: [(1.0, 23, 0.0, True)], 3: [(1.0, 23, 0.0, True)]}, 24: {0: [(1.0, 24, 0.0, True)], 1: [(1.0, 24, 0.0, True)], 2: [(1.0, 24, 0.0, True)], 3: [(1.0, 24, 0.0, True)]}, 25: {0: [(1.0, 25, 0.0, True)], 1: [(1.0, 25, 0.0, True)], 2: [(1.0, 25, 0.0, True)], 3: [(1.0, 25, 0.0, True)]}, 26: {0: [(1.0, 24, 0.0, True)], 1: [(1.0, 26, 0.0, False)], 2: [(1.0, 28, 0.0, False)], 3: [(1.0, 18, 0.0, False)]}, 27: {0: [(1.0, 25, 0.0, True)], 1: [(1.0, 27, 0.0, False)], 2: [(1.0, 29, 0.0, False)], 3: [(1.0, 19, 0.0, False)]}, 28: {0: [(1.0, 26, 0.0, False)], 1: [(1.0, 28, 0.0, False)], 2: [(1.0, 28, 0.0, False)], 3: [(1.0, 20, 0.0, False)]}, 29: {0: [(1.0, 27, 0.0, False)], 1: [(1.0, 29, 0.0, False)], 2: [(1.0, 31, 1.0, True)], 3: [(1.0, 21, 0.0, False)]}, 30: {0: [(1.0, 30, 0.0, True)], 1: [(1.0, 30, 0.0, True)], 2: [(1.0, 30, 0.0, True)], 3: [(1.0, 30, 0.0, True)]}, 31: {0: [(1.0, 31, 0.0, True)], 1: [(1.0, 31, 0.0, True)], 2: [(1.0, 31, 0.0, True)], 3: [(1.0, 31, 0.0, True)]}}

# %% [markdown]
# The exact way you represent each state and each action is up to you! But... do atleast write down in a comment or something how you represent the states and action in the MDP. So i don't have to spend time deciphering.
#
# Note: For additional challenges
# - Make this grid-world also stochastic like Frozen Lake
# - Make a function that allows you to input in the locations of the holes, the door(goal state) and the key and using that it will generate and return the MDP

# %% [markdown]
# ## Environment 4 - Lights Out

# %% [markdown]
# **Lights out** is a deterministic puzzle game which consists of a 5x5 grid of lights which can either be on or off.
#
# When the game begins a random set of these lights will be switched on. Pressing any light will toggle it (toggle means if the light was on then it will become off and if it was off then it will become on) and it will also toggle all of its neighbours.
#
# ![image of the game](./images/LightsOutIllustration.png)
#
# Note: so any non-edge and non-corner cell action will toggle 5 lights, an edge cell action would toggle 4 lights and a corner cell action only toggles 3 lights.

# %% [markdown]
# The goal of the game is to find a sequence of moves to switch off all the lights. Now i'm not gonna make you solve this instead we are going to represent this as a deterministic MDP, where
# - the states should represent the game grid layout
# - the actions are the cells you wish to toggle
# - Give a reward of 1 when solved
# - the ONLY terminal state is the fully solved state
#
# Since 5x5 is pretty big we will restrict ourselves to a **4x4** grid and represent it as an MDP instead

# %%
# You can implements any helper function or other variables to help you implement it
#each cell is represented as 0,1,2,..15 in order, now the state is defined as summation of 2^(cell)*(0 if off,1 if on)
def ison(cell,state):
    val=(state//(2**cell))%2
    return bool(val)
def gen():
    mdp={}
    for state in range(0,2**5):
        mdp[state]={}
        for action in range(0,15):
            nextstate=state
            for i in [4,-4]:
                if (action+i) in range(0,2**4):
                    if ison(action+i,state):
                        nextstate-=2**(action+i)
                    else:
                        nextstate+=2**(action+i)
            for i in [-1,1]:
                cell=action+i
                if (i==1 and cell%4!=0) or (i==-1 and cell%4!=3):
                    if ison(cell,state):
                        nextstate-=2**(cell)
                    else:
                        nextstate+=2**(cell)
            if nextstate==0:
                rew=True
            else:
                rew=False
            mdp[state][action]=[(1,nextstate,int(rew),rew)]

    return mdp
lo_map = gen()
print(lo_map)
# Out:
# {0: {0: [(1, 18, 0, False)], 1: [(1, 37, 0, False)], 2: [(1, 74, 0, False)], 3: [(1, 132, 0, False)], 4: [(1, 289, 0, False)], 5: [(1, 594, 0, False)], 6: [(1, 1188, 0, False)], 7: [(1, 2120, 0, False)], 8: [(1, 4624, 0, False)], 9: [(1, 9504, 0, False)], 10: [(1, 19008, 0, False)], 11: [(1, 33920, 0, False)], 12: [(1, 8448, 0, False)], 13: [(1, 20992, 0, False)], 14: [(1, 41984, 0, False)]}, 1: {0: [(1, 19, 0, False)], 1: [(1, 36, 0, False)], 2: [(1, 75, 0, False)], 3: [(1, 133, 0, False)], 4: [(1, 288, 0, False)], 5: [(1, 595, 0, False)], 6: [(1, 1189, 0, False)], 7: [(1, 2121, 0, False)], 8: [(1, 4625, 0, False)], 9: [(1, 9505, 0, False)], 10: [(1, 19009, 0, False)], 11: [(1, 33921, 0, False)], 12: [(1, 8449, 0, False)], 13: [(1, 20993, 0, False)], 14: [(1, 41985, 0, False)]}, 2: {0: [(1, 16, 0, False)], 1: [(1, 39, 0, False)], 2: [(1, 72, 0, False)], 3: [(1, 134, 0, False)], 4: [(1, 291, 0, False)], 5: [(1, 592, 0, False)], 6: [(1, 1190, 0, False)], 7: [(1, 2122, 0, False)], 8: [(1, 4626, 0, False)], 9: [(1, 9506, 0, False)], 10: [(1, 19010, 0, False)], 11: [(1, 33922, 0, False)], 12: [(1, 8450, 0, False)], 13: [(1, 20994, 0, False)], 14: [(1, 41986, 0, False)]}, 3: {0: [(1, 17, 0, False)], 1: [(1, 38, 0, False)], 2: [(1, 73, 0, False)], 3: [(1, 135, 0, False)], 4: [(1, 290, 0, False)], 5: [(1, 593, 0, False)], 6: [(1, 1191, 0, False)], 7: [(1, 2123, 0, False)], 8: [(1, 4627, 0, False)], 9: [(1, 9507, 0, False)], 10: [(1, 19011, 0, False)], 11: [(1, 33923, 0, False)], 12: [(1, 8451, 0, False)], 13: [(1, 20995, 0, False)], 14: [(1, 41987, 0, False)]}, 4: {0: [(1, 22, 0, False)], 1: [(1, 33, 0, False)], 2: [(1, 78, 0, False)], 3: [(1, 128, 0, False)], 4: [(1, 293, 0, False)], 5: [(1, 598, 0, False)], 6: [(1, 1184, 0, False)], 7: [(1, 2124, 0, False)], 8